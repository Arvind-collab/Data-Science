# %% [markdown]
# # ITP Mini Project

# %% [markdown]
# We all have to maintain our own personal expenses in day to day life. It’s very normal for us to lose track of them and end up going out of budget. We require a way to keep ourself in within budget.
#
# This is where we can explore our skills in Python to come up with a solution. We can create a python program that allows you to keep track of the finance expenses.
#
# With the Finance Tracker, users can easily set a budget and add up their expenses to make better financial decisions. Anything beyond the budget will not be added up.
#
# **Objective:**To Estimate the Personal Financial Budget at the End of the Month.

# %%
# Write the Code here:-
def main():
    budget=1000
    choosen=0
    while choosen!=8:
        print('Your current budget is', budget)
        print("Enter your choice\n1.Add expenses\n2.Delete Expenses\n3.Add Revenue\n4.Delete Revenue\n5.Add Debt\n6.Remove Debt\n7.Change budget\n8.Close")
        choosen=input()
        while choosen.isdigit()==False:
            print('Invalid input, please enter a number: _') 
            choosen=input() 
        choosen=int(choosen)
        if choosen==1:
            budget=addExp(budget)
            upd()
        elif choosen==2:
            budget=delExp(budget)
            upd()
        elif choosen==3:
            budget=addRev(budget) 
            upd()
        elif choosen==4:
            budget=delRev(budget)
            upd()
        elif choosen==5:
            budget=addDebt(budget)
            upd()
        elif choosen==6:
            budget=remDebt(budget)
            upd()
        elif choosen==7:
            budget=changeB(budget)
            upd()
        elif choosen==8:
            print('Closed!')
        else:
            print('Uh Oh! Wrong Input\nTry again..') 
            
def addExp(x):
            entry= input('Okay! Cool.. Let\'s add an expense. Please enter your expense in Rupee : ')
            while entry.isdigit()==False or int(entry)<0 or (x-int(entry))<0:
                print('Invalid input, please enter an allowed number: _') 
                entry=input()   
            entry=int(entry) 
            return x-entry 
def delExp(x):
            entry= input('It\'s alright man. Please enter your expense to delete in Rupee : ')
            while entry.isdigit()==False or int(entry)<0:
                print('Invalid input, please enter an allowed number: _') 
                entry=input() 
            entry=int(entry) 
            return x+entry
def addRev(x):
            entry= input('Hmm.. Let\'s add a revenue. Please enter your revenue in Rupee : ')
            while entry.isdigit()==False or int(entry)<0:
                print('Invalid input, please enter an allowed number: _') 
                entry=input() 
            entry=int(entry) 
            return x+entry
def delRev(x):
            entry= input('It\'s alright.. Let\'s remove revenue. Please enter your revenue in Rupee : ')
            while entry.isdigit()==False or int(entry)<0 or (x-int(entry))<0:
                print('Invalid input, please enter an allowed number: _') 
                entry=input()   
            entry=int(entry) 
            return x-entry
def addDebt(x):
            entry= input('Please enter the money you borrowed in Rupee : ')
            while entry.isdigit()==False or int(entry)<0:
                print('Invalid input, please enter an allowed number: _') 
                entry=input() 
            entry=int(entry)
            return x+entry
def remDebt(x):
            entry= input('Please enter the debt you paid back from your budget in Rupee : ')
            while entry.isdigit()==False or int(entry)<0 or (x-int(entry))<0:
                print('Invalid input, please enter an allowed number: _') 
                entry=input()   
            entry=int(entry) 
            return x-entry
def changeB(x):
            entry= input('Please enter the amount you want to set as your new budget : ')
            while entry.isdigit()==False or int(entry)<0:
                print('Invalid input, please enter an allowed number: _') 
                entry=input() 
            entry=int(entry) 
            return entry
def upd():
    print('Updation successful!')
    
main()
# Out:
# Your current budget is 1000
# Enter your choice
# 1.Add expenses
# 2.Delete Expenses
# 3.Add Revenue
# 4.Delete Revenue
# 5.Add Debt
# 6.Remove Debt
# 7.Change budget
# 8.Close
# 1
# Okay! Cool.. Let's add an expense. Please enter your expense in Rupee : 12
# Updation successful!
# Your current budget is 988
# Enter your choice
# 1.Add expenses
# 2.Delete Expenses
# 3.Add Revenue
# 4.Delete Revenue
# 5.Add Debt
# 6.Remove Debt
# 7.Change budget
# 8.Close
# 1
# Okay! Cool.. Let's add an expense. Please enter your expense in Rupee : 12
# Updation successful!
# Your current budget is 976
# Enter your choice
# 1.Add expenses
# 2.Delete Expenses
# 3.Add Revenue
# 4.Delete Revenue
# 5.Add Debt
# 6.Remove Debt
# 7.Change budget
# 8.Close
# 1
# Okay! Cool.. Let's add an expense. Please enter your expense in Rupee : 0
# Updation successful!
# Your current budget is 976
# Enter your choice
# 1.Add expenses
# 2.Delete Expenses
# 3.Add Revenue
# 4.Delete Revenue
# 5.Add Debt
# 6.Remove Debt
# ...

# %%
90000000000000000%26
# Out:
# 14

# %%
print((chr(int(14))+" ")*55)
